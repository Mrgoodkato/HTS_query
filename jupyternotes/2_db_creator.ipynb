# %%
import json, pymongo, os, re
# %run ../.env/credentialsDB.py

# %%
class Connection:
    """Class that connects to the database creating all necessary methods for connection and closing connection, as well as the base database for adding new HTS records and the string_dict collection too
    """

    def __init__(self, db_path: str):
        """_init_ function of the class, defines the connection variables

        Args:
            db_path (str): Path to the database connection on MongoDB
        """

        self.client = pymongo.MongoClient(db_path)
        self.db = self.client['hts']
        self.collection_records = self.db['hts_records']
        self.collection_string_dict = self.db['string_dict']
        

    def closeConnection(self):
        """Close connection function, closes current connection created in the Connection class
        """
        self.client.close()

def addHTSRecord(folder_path: str, record: str, collection: pymongo.collection.Collection):
    """Specific function used by the createHTSDatabase() in order to add each document into the hts collection

    Args:
        folder_path (str): Path to folder where .json hts chapters are stored
        record (str): Name of file to be opened for addition
        collection (pymongo.collection.Collection): Pymongo collection object gathered from the Connection class
    """

    with open(f'{folder_path}{record}') as sec:


        data = json.load(sec)
        header = re.sub(r'\.json', '', record)

        hts_record = {
            'header': header,
            'data': data
        }

        try:
            collection.insert_one(hts_record)
        except:
            print(f'Error creating record in db for file {sec}')

def queryHTSString(chaps: list, hts_collection: pymongo.collection.Collection):
    """Function helper of addStrRecord() that adds the ObjectId of each of the chapters in the list created in the string_dict json object.

    Args:
        chaps (list): List of chapters to be queried in Mongo
        hts_collection (pymongo.collection.Collection): HTS collection already created and populated with chapter information for query

    Returns:
        list: Returns a list of ObjectIds from the hts collection from MongoDB to replace the string_dict list of chapters
    """

    ids = []

    for chap in chaps:

        #MongoDB returns a cursor iterator when we perform a find() query or aggregator as well, we need to also iterate it to gather the documents, or document
        cursor = hts_collection.find({ 'header': chap })

        for document in cursor:
            ids.append(document['_id'])
    
    return ids

def addStrRecord(str_chaps: list, key: str, connection: Connection):
    """Collects all the necessary information for the creation of each document in the string_dict collection

    Args:
        str_chaps (list): Chapter list from the original string_dict json file that will be converted in its corresponding ObjectIds from the HTS collection in MongoDB
        key (str): Key word to be added to the collection representing the document
        connection (Connection): Connection class object that connects to the MongoDB instance
    """

    try:
        record = {
            'string': key,
            'chaps': queryHTSString(str_chaps, connection.collection_records)
        }
        connection.collection_string_dict.insert_one(record)
    except Exception as e:
        print(f'Error creating record in db for str_dict key: {key}, error: {e}')

# %%
def createHTSDatabase(path_records: str, file_list: list, connection: Connection):
    """Main function to create the HTS database of records

    Args:
        path_records (str): Path to the .json divided record files
        file_list (list): List of filenames from the path_records for iteration
        connection (Connection): Connection class object that connects to the MongoDB instance
    """
    #Create Collection of records
    for file in file_list:
        print(f'Creating document {file} in hts_records collection...')
        addHTSRecord(path_records, file, connection.collection_records)

    print('Completed hts_records collection!')

def createStringDict(path_string_dict: str, connection: Connection):
    """Main function to create the string_dict collection in MongoDB

    Args:
        path_string_dict (str): Path to the json file with the string_dict information
        connection (Connection): Connection class object that connects to the MongoDB instance
    """

    #Create Collection of string_dict
    with open(f'{path_string_dict}string_dict.json', 'r') as string_file:

        string_dict_raw = json.load(string_file)

        for key in string_dict_raw.keys():
            print(f'Creating document for <{key}> in string_dict collection...')
            addStrRecord(string_dict_raw[key], key, connection)
            
        print('Completed creating string_dict collection!')

# %% [markdown]
# Execution of the database creation functions and definition of the paths and lists used. Do not use if DB is already created!

# %%
folder_path = '../db_hts/temp/NEW_test_files/'
string_folder_path = '../db_hts/temp/NEW_test_string_dict/'

file_list = os.listdir(folder_path)

connection = Connection(f'{PATH_DB}{USER_DB}:{PW_DB}@{CLUSTER_DB}')

createHTSDatabase(folder_path, file_list, connection)
createStringDict(string_folder_path, connection)

connection.closeConnection()
# Out:
# Creating document 0101.json in hts_records collection...
# Creating document 0102.json in hts_records collection...
# Creating document 0103.json in hts_records collection...
# Creating document 0104.json in hts_records collection...
# Creating document 0105.json in hts_records collection...
# Creating document 0106.json in hts_records collection...
# Creating document 0201.json in hts_records collection...
# Creating document 0202.json in hts_records collection...
# Creating document 0203.json in hts_records collection...
# Creating document 0204.json in hts_records collection...
# Creating document 0205.json in hts_records collection...
# Creating document 0206.json in hts_records collection...
# Creating document 0207.json in hts_records collection...
# Creating document 0208.json in hts_records collection...
# Creating document 0209.json in hts_records collection...
# Creating document 0210.json in hts_records collection...
# Creating document 0301.json in hts_records collection...
# Creating document 0302.json in hts_records collection...
# Creating document 0303.json in hts_records collection...
# Creating document 0304.json in hts_records collection...
# Creating document 0305.json in hts_records collection...
# Creating document 0306.json in hts_records collection...
# Creating document 0307.json in hts_records collection...
# Creating document 0308.json in hts_records collection...
# Creating document 0309.json in hts_records collection...
# Creating document 0401.json in hts_records collection...
# Creating document 0402.json in hts_records collection...
# Creating document 0403.json in hts_records collection...
# Creating document 0404.json in hts_records collection...
# Creating document 0405.json in hts_records collection...
# Creating document 0406.json in hts_records collection...
# Creating document 0407.json in hts_records collection...
# Creating document 0408.json in hts_records collection...
# Creating document 0409.json in hts_records collection...
# Creating document 0410.json in hts_records collection...
# Creating document 0501.json in hts_records collection...
# Creating document 0502.json in hts_records collection...
# Creating document 0504.json in hts_records collection...
# Creating document 0505.json in hts_records collection...
# Creating document 0506.json in hts_records collection...
# Creating document 0507.json in hts_records collection...
# Creating document 0508.json in hts_records collection...
# Creating document 0510.json in hts_records collection...
# Creating document 0511.json in hts_records collection...
# Creating document 0601.json in hts_records collection...
# Creating document 0602.json in hts_records collection...
# Creating document 0603.json in hts_records collection...
# Creating document 0604.json in hts_records collection...
# Creating document 0701.json in hts_records collection...
# Creating document 0702.json in hts_records collection...
# Creating document 0703.json in hts_records collection...
# Creating document 0704.json in hts_records collection...
# Creating document 0705.json in hts_records collection...
# Creating document 0706.json in hts_records collection...
# Creating document 0707.json in hts_records collection...
# Creating document 0708.json in hts_records collection...
# Creating document 0709.json in hts_records collection...
# Creating document 0710.json in hts_records collection...
# Creating document 0711.json in hts_records collection...
# Creating document 0712.json in hts_records collection...
# Creating document 0713.json in hts_records collection...
# Creating document 0714.json in hts_records collection...
# Creating document 0801.json in hts_records collection...
# Creating document 0802.json in hts_records collection...
# Creating document 0803.json in hts_records collection...
# Creating document 0804.json in hts_records collection...
# Creating document 0805.json in hts_records collection...
# Creating document 0806.json in hts_records collection...
# Creating document 0807.json in hts_records collection...
# Creating document 0808.json in hts_records collection...
# Creating document 0809.json in hts_records collection...
# Creating document 0810.json in hts_records collection...
# Creating document 0811.json in hts_records collection...
# Creating document 0812.json in hts_records collection...
# Creating document 0813.json in hts_records collection...
# Creating document 0814.json in hts_records collection...
# Creating document 0901.json in hts_records collection...
# Creating document 0902.json in hts_records collection...
# Creating document 0903.json in hts_records collection...
# Creating document 0904.json in hts_records collection...
# Creating document 0905.json in hts_records collection...
# Creating document 0906.json in hts_records collection...
# Creating document 0907.json in hts_records collection...
# Creating document 0908.json in hts_records collection...
# Creating document 0909.json in hts_records collection...
# Creating document 0910.json in hts_records collection...
# Creating document 1001.json in hts_records collection...
# Creating document 1002.json in hts_records collection...
# Creating document 1003.json in hts_records collection...
# Creating document 1004.json in hts_records collection...
# Creating document 1005.json in hts_records collection...
# Creating document 1006.json in hts_records collection...
# Creating document 1007.json in hts_records collection...
# Creating document 1008.json in hts_records collection...
# Creating document 1101.json in hts_records collection...
# Creating document 1102.json in hts_records collection...
# Creating document 1103.json in hts_records collection...
# Creating document 1104.json in hts_records collection...
# Creating document 1105.json in hts_records collection...
# Creating document 1106.json in hts_records collection...
# Creating document 1107.json in hts_records collection...
# Creating document 1108.json in hts_records collection...
# Creating document 1109.json in hts_records collection...
# Creating document 1201.json in hts_records collection...
# Creating document 1202.json in hts_records collection...
# Creating document 1203.json in hts_records collection...
# Creating document 1204.json in hts_records collection...
# Creating document 1205.json in hts_records collection...
# Creating document 1206.json in hts_records collection...
# Creating document 1207.json in hts_records collection...
# Creating document 1208.json in hts_records collection...
# Creating document 1209.json in hts_records collection...
# Creating document 1210.json in hts_records collection...
# Creating document 1211.json in hts_records collection...
# Creating document 1212.json in hts_records collection...
# Creating document 1213.json in hts_records collection...
# Creating document 1214.json in hts_records collection...
# Creating document 1301.json in hts_records collection...
# Creating document 1302.json in hts_records collection...
# Creating document 1401.json in hts_records collection...
# Creating document 1404.json in hts_records collection...
# Creating document 1501.json in hts_records collection...
# Creating document 1502.json in hts_records collection...
# Creating document 1503.json in hts_records collection...
# Creating document 1504.json in hts_records collection...
# Creating document 1505.json in hts_records collection...
# Creating document 1506.json in hts_records collection...
# Creating document 1507.json in hts_records collection...
# Creating document 1508.json in hts_records collection...
# Creating document 1509.json in hts_records collection...
# Creating document 1510.json in hts_records collection...
# Creating document 1511.json in hts_records collection...
# Creating document 1512.json in hts_records collection...
# Creating document 1513.json in hts_records collection...
# Creating document 1514.json in hts_records collection...
# Creating document 1515.json in hts_records collection...
# Creating document 1516.json in hts_records collection...
# Creating document 1517.json in hts_records collection...
# Creating document 1518.json in hts_records collection...
# Creating document 1520.json in hts_records collection...
# Creating document 1521.json in hts_records collection...
# Creating document 1522.json in hts_records collection...
# Creating document 1601.json in hts_records collection...
# Creating document 1602.json in hts_records collection...
# Creating document 1603.json in hts_records collection...
# Creating document 1604.json in hts_records collection...
# Creating document 1605.json in hts_records collection...
# Creating document 1701.json in hts_records collection...
# Creating document 1702.json in hts_records collection...
# Creating document 1703.json in hts_records collection...
# Creating document 1704.json in hts_records collection...
# Creating document 1801.json in hts_records collection...
# Creating document 1802.json in hts_records collection...
# Creating document 1803.json in hts_records collection...
# Creating document 1804.json in hts_records collection...
# Creating document 1805.json in hts_records collection...
# Creating document 1806.json in hts_records collection...
# Creating document 1901.json in hts_records collection...
# Creating document 1902.json in hts_records collection...
# Creating document 1903.json in hts_records collection...
# Creating document 1904.json in hts_records collection...
# Creating document 1905.json in hts_records collection...
# Creating document 2001.json in hts_records collection...
# Creating document 2002.json in hts_records collection...
# Creating document 2003.json in hts_records collection...
# Creating document 2004.json in hts_records collection...
# Creating document 2005.json in hts_records collection...
# Creating document 2006.json in hts_records collection...
# Creating document 2007.json in hts_records collection...
# Creating document 2008.json in hts_records collection...
# Creating document 2009.json in hts_records collection...
# Creating document 2101.json in hts_records collection...
# Creating document 2102.json in hts_records collection...
# Creating document 2103.json in hts_records collection...
# Creating document 2104.json in hts_records collection...
# Creating document 2105.json in hts_records collection...
# Creating document 2106.json in hts_records collection...
# Creating document 2201.json in hts_records collection...
# Creating document 2202.json in hts_records collection...
# Creating document 2203.json in hts_records collection...
# Creating document 2204.json in hts_records collection...
# Creating document 2205.json in hts_records collection...
# Creating document 2206.json in hts_records collection...
# Creating document 2207.json in hts_records collection...
# Creating document 2208.json in hts_records collection...
# Creating document 2209.json in hts_records collection...
# Creating document 2301.json in hts_records collection...
# Creating document 2302.json in hts_records collection...
# Creating document 2303.json in hts_records collection...
# Creating document 2304.json in hts_records collection...
# Creating document 2305.json in hts_records collection...
# Creating document 2306.json in hts_records collection...
# Creating document 2307.json in hts_records collection...
# Creating document 2308.json in hts_records collection...
# Creating document 2309.json in hts_records collection...
# Creating document 2401.json in hts_records collection...
# Creating document 2402.json in hts_records collection...
# Creating document 2403.json in hts_records collection...
# Creating document 2404.json in hts_records collection...
# Creating document 2501.json in hts_records collection...
# Creating document 2502.json in hts_records collection...
# Creating document 2503.json in hts_records collection...
# Creating document 2504.json in hts_records collection...
# Creating document 2505.json in hts_records collection...
# Creating document 2506.json in hts_records collection...
# Creating document 2507.json in hts_records collection...
# Creating document 2508.json in hts_records collection...
# Creating document 2509.json in hts_records collection...
# Creating document 2510.json in hts_records collection...
# Creating document 2511.json in hts_records collection...
# Creating document 2512.json in hts_records collection...
# Creating document 2513.json in hts_records collection...
# Creating document 2514.json in hts_records collection...
# Creating document 2515.json in hts_records collection...
# Creating document 2516.json in hts_records collection...
# Creating document 2517.json in hts_records collection...
# Creating document 2518.json in hts_records collection...
# Creating document 2519.json in hts_records collection...
# Creating document 2520.json in hts_records collection...
# Creating document 2521.json in hts_records collection...
# Creating document 2522.json in hts_records collection...
# Creating document 2523.json in hts_records collection...
# Creating document 2524.json in hts_records collection...
# Creating document 2525.json in hts_records collection...
# Creating document 2526.json in hts_records collection...
# Creating document 2528.json in hts_records collection...
# Creating document 2529.json in hts_records collection...
# Creating document 2530.json in hts_records collection...
# Creating document 2601.json in hts_records collection...
# Creating document 2602.json in hts_records collection...
# Creating document 2603.json in hts_records collection...
# Creating document 2604.json in hts_records collection...
# Creating document 2605.json in hts_records collection...
# Creating document 2606.json in hts_records collection...
# Creating document 2607.json in hts_records collection...
# Creating document 2608.json in hts_records collection...
# Creating document 2609.json in hts_records collection...
# Creating document 2610.json in hts_records collection...
# Creating document 2611.json in hts_records collection...
# Creating document 2612.json in hts_records collection...
# Creating document 2613.json in hts_records collection...
# Creating document 2614.json in hts_records collection...
# Creating document 2615.json in hts_records collection...
# Creating document 2616.json in hts_records collection...
# Creating document 2617.json in hts_records collection...
# Creating document 2618.json in hts_records collection...
# Creating document 2619.json in hts_records collection...
# Creating document 2620.json in hts_records collection...
# Creating document 2621.json in hts_records collection...
# Creating document 2701.json in hts_records collection...
# Creating document 2702.json in hts_records collection...
# Creating document 2703.json in hts_records collection...
# Creating document 2704.json in hts_records collection...
# Creating document 2705.json in hts_records collection...
# Creating document 2706.json in hts_records collection...
# Creating document 2707.json in hts_records collection...
# Creating document 2708.json in hts_records collection...
# Creating document 2709.json in hts_records collection...
# Creating document 2710.json in hts_records collection...
# Creating document 2711.json in hts_records collection...
# Creating document 2712.json in hts_records collection...
# Creating document 2713.json in hts_records collection...
# Creating document 2714.json in hts_records collection...
# Creating document 2715.json in hts_records collection...
# Creating document 2716.json in hts_records collection...
# Creating document 2801.json in hts_records collection...
# Creating document 2802.json in hts_records collection...
# Creating document 2803.json in hts_records collection...
# Creating document 2804.json in hts_records collection...
# Creating document 2805.json in hts_records collection...
# Creating document 2806.json in hts_records collection...
# Creating document 2807.json in hts_records collection...
# Creating document 2808.json in hts_records collection...
# Creating document 2809.json in hts_records collection...
# Creating document 2810.json in hts_records collection...
# Creating document 2811.json in hts_records collection...
# Creating document 2812.json in hts_records collection...
# Creating document 2813.json in hts_records collection...
# Creating document 2814.json in hts_records collection...
# Creating document 2815.json in hts_records collection...
# Creating document 2816.json in hts_records collection...
# Creating document 2817.json in hts_records collection...
# Creating document 2818.json in hts_records collection...
# Creating document 2819.json in hts_records collection...
# Creating document 2820.json in hts_records collection...
# Creating document 2821.json in hts_records collection...
# Creating document 2822.json in hts_records collection...
# Creating document 2823.json in hts_records collection...
# Creating document 2824.json in hts_records collection...
# Creating document 2825.json in hts_records collection...
# Creating document 2826.json in hts_records collection...
# Creating document 2827.json in hts_records collection...
# Creating document 2828.json in hts_records collection...
# Creating document 2829.json in hts_records collection...
# Creating document 2830.json in hts_records collection...
# Creating document 2831.json in hts_records collection...
# Creating document 2832.json in hts_records collection...
# Creating document 2833.json in hts_records collection...
# Creating document 2834.json in hts_records collection...
# Creating document 2835.json in hts_records collection...
# Creating document 2836.json in hts_records collection...
# Creating document 2837.json in hts_records collection...
# Creating document 2839.json in hts_records collection...
# Creating document 2840.json in hts_records collection...
# Creating document 2841.json in hts_records collection...
# Creating document 2842.json in hts_records collection...
# Creating document 2843.json in hts_records collection...
# Creating document 2844.json in hts_records collection...
# Creating document 2845.json in hts_records collection...
# Creating document 2846.json in hts_records collection...
# Creating document 2847.json in hts_records collection...
# Creating document 2849.json in hts_records collection...
# Creating document 2850.json in hts_records collection...
# Creating document 2852.json in hts_records collection...
# Creating document 2853.json in hts_records collection...
# Creating document 2901.json in hts_records collection...
# Creating document 2902.json in hts_records collection...
# Creating document 2903.json in hts_records collection...
# Creating document 2904.json in hts_records collection...
# Creating document 2905.json in hts_records collection...
# Creating document 2906.json in hts_records collection...
# Creating document 2907.json in hts_records collection...
# Creating document 2908.json in hts_records collection...
# Creating document 2909.json in hts_records collection...
# Creating document 2910.json in hts_records collection...
# Creating document 2911.json in hts_records collection...
# Creating document 2912.json in hts_records collection...
# Creating document 2913.json in hts_records collection...
# Creating document 2914.json in hts_records collection...
# Creating document 2915.json in hts_records collection...
# Creating document 2916.json in hts_records collection...
# Creating document 2917.json in hts_records collection...
# Creating document 2918.json in hts_records collection...
# Creating document 2919.json in hts_records collection...
# Creating document 2920.json in hts_records collection...
# Creating document 2921.json in hts_records collection...
# Creating document 2922.json in hts_records collection...
# Creating document 2923.json in hts_records collection...
# Creating document 2924.json in hts_records collection...
# Creating document 2925.json in hts_records collection...
# Creating document 2926.json in hts_records collection...
# Creating document 2927.json in hts_records collection...
# Creating document 2928.json in hts_records collection...
# Creating document 2929.json in hts_records collection...
# Creating document 2930.json in hts_records collection...
# Creating document 2931.json in hts_records collection...
# Creating document 2932.json in hts_records collection...
# Creating document 2933.json in hts_records collection...
# Creating document 2934.json in hts_records collection...
# Creating document 2935.json in hts_records collection...
# Creating document 2936.json in hts_records collection...
# Creating document 2937.json in hts_records collection...
# Creating document 2938.json in hts_records collection...
# Creating document 2939.json in hts_records collection...
# Creating document 2940.json in hts_records collection...
# Creating document 2941.json in hts_records collection...
# Creating document 2942.json in hts_records collection...
# Creating document 3001.json in hts_records collection...
# Creating document 3002.json in hts_records collection...
# Creating document 3003.json in hts_records collection...
# Creating document 3004.json in hts_records collection...
# Creating document 3005.json in hts_records collection...
# Creating document 3006.json in hts_records collection...
# Creating document 3101.json in hts_records collection...
# Creating document 3102.json in hts_records collection...
# Creating document 3103.json in hts_records collection...
# Creating document 3104.json in hts_records collection...
# Creating document 3105.json in hts_records collection...
# Creating document 3201.json in hts_records collection...
# Creating document 3202.json in hts_records collection...
# Creating document 3203.json in hts_records collection...
# Creating document 3204.json in hts_records collection...
# Creating document 3205.json in hts_records collection...
# Creating document 3206.json in hts_records collection...
# Creating document 3207.json in hts_records collection...
# Creating document 3208.json in hts_records collection...
# Creating document 3209.json in hts_records collection...
# Creating document 3210.json in hts_records collection...
# Creating document 3211.json in hts_records collection...
# Creating document 3212.json in hts_records collection...
# Creating document 3213.json in hts_records collection...
# Creating document 3214.json in hts_records collection...
# Creating document 3215.json in hts_records collection...
# Creating document 3301.json in hts_records collection...
# Creating document 3302.json in hts_records collection...
# Creating document 3303.json in hts_records collection...
# Creating document 3304.json in hts_records collection...
# Creating document 3305.json in hts_records collection...
# Creating document 3306.json in hts_records collection...
# Creating document 3307.json in hts_records collection...
# Creating document 3401.json in hts_records collection...
# Creating document 3402.json in hts_records collection...
# Creating document 3403.json in hts_records collection...
# Creating document 3404.json in hts_records collection...
# Creating document 3405.json in hts_records collection...
# Creating document 3406.json in hts_records collection...
# Creating document 3407.json in hts_records collection...
# Creating document 3501.json in hts_records collection...
# Creating document 3502.json in hts_records collection...
# Creating document 3503.json in hts_records collection...
# Creating document 3504.json in hts_records collection...
# Creating document 3505.json in hts_records collection...
# Creating document 3506.json in hts_records collection...
# Creating document 3507.json in hts_records collection...
# Creating document 3601.json in hts_records collection...
# Creating document 3602.json in hts_records collection...
# Creating document 3603.json in hts_records collection...
# Creating document 3604.json in hts_records collection...
# Creating document 3605.json in hts_records collection...
# Creating document 3606.json in hts_records collection...
# Creating document 3701.json in hts_records collection...
# Creating document 3702.json in hts_records collection...
# Creating document 3703.json in hts_records collection...
# Creating document 3704.json in hts_records collection...
# Creating document 3705.json in hts_records collection...
# Creating document 3706.json in hts_records collection...
# Creating document 3707.json in hts_records collection...
# Creating document 3801.json in hts_records collection...
# Creating document 3802.json in hts_records collection...
# Creating document 3803.json in hts_records collection...
# Creating document 3804.json in hts_records collection...
# Creating document 3805.json in hts_records collection...
# Creating document 3806.json in hts_records collection...
# Creating document 3807.json in hts_records collection...
# Creating document 3808.json in hts_records collection...
# Creating document 3809.json in hts_records collection...
# Creating document 3810.json in hts_records collection...
# Creating document 3811.json in hts_records collection...
# Creating document 3812.json in hts_records collection...
# Creating document 3813.json in hts_records collection...
# Creating document 3814.json in hts_records collection...
# Creating document 3815.json in hts_records collection...
# Creating document 3816.json in hts_records collection...
# Creating document 3817.json in hts_records collection...
# Creating document 3818.json in hts_records collection...
# Creating document 3819.json in hts_records collection...
# Creating document 3820.json in hts_records collection...
# Creating document 3821.json in hts_records collection...
# Creating document 3822.json in hts_records collection...
# Creating document 3823.json in hts_records collection...
# Creating document 3824.json in hts_records collection...
# Creating document 3825.json in hts_records collection...
# Creating document 3826.json in hts_records collection...
# Creating document 3827.json in hts_records collection...
# Creating document 3901.json in hts_records collection...
# Creating document 3902.json in hts_records collection...
# Creating document 3903.json in hts_records collection...
# Creating document 3904.json in hts_records collection...
# Creating document 3905.json in hts_records collection...
# Creating document 3906.json in hts_records collection...
# Creating document 3907.json in hts_records collection...
# Creating document 3908.json in hts_records collection...
# Creating document 3909.json in hts_records collection...
# Creating document 3910.json in hts_records collection...
# Creating document 3911.json in hts_records collection...
# Creating document 3912.json in hts_records collection...
# Creating document 3913.json in hts_records collection...
# Creating document 3914.json in hts_records collection...
# Creating document 3915.json in hts_records collection...
# Creating document 3916.json in hts_records collection...
# Creating document 3917.json in hts_records collection...
# Creating document 3918.json in hts_records collection...
# Creating document 3919.json in hts_records collection...
# Creating document 3920.json in hts_records collection...
# Creating document 3921.json in hts_records collection...
# Creating document 3922.json in hts_records collection...
# Creating document 3923.json in hts_records collection...
# Creating document 3924.json in hts_records collection...
# Creating document 3925.json in hts_records collection...
# Creating document 3926.json in hts_records collection...
# Creating document 4001.json in hts_records collection...
# Creating document 4002.json in hts_records collection...
# Creating document 4003.json in hts_records collection...
# Creating document 4004.json in hts_records collection...
# Creating document 4005.json in hts_records collection...
# Creating document 4006.json in hts_records collection...
# Creating document 4007.json in hts_records collection...
# Creating document 4008.json in hts_records collection...
# Creating document 4009.json in hts_records collection...
# Creating document 4010.json in hts_records collection...
# Creating document 4011.json in hts_records collection...
# Creating document 4012.json in hts_records collection...
# Creating document 4013.json in hts_records collection...
# Creating document 4014.json in hts_records collection...
# Creating document 4015.json in hts_records collection...
# Creating document 4016.json in hts_records collection...
# Creating document 4017.json in hts_records collection...
# Creating document 4101.json in hts_records collection...
# Creating document 4102.json in hts_records collection...
# Creating document 4103.json in hts_records collection...
# Creating document 4104.json in hts_records collection...
# Creating document 4105.json in hts_records collection...
# Creating document 4106.json in hts_records collection...
# Creating document 4107.json in hts_records collection...
# Creating document 4112.json in hts_records collection...
# Creating document 4113.json in hts_records collection...
# Creating document 4114.json in hts_records collection...
# Creating document 4115.json in hts_records collection...
# Creating document 4201.json in hts_records collection...
# Creating document 4202.json in hts_records collection...
# Creating document 4203.json in hts_records collection...
# Creating document 4205.json in hts_records collection...
# Creating document 4206.json in hts_records collection...
# Creating document 4301.json in hts_records collection...
# Creating document 4302.json in hts_records collection...
# Creating document 4303.json in hts_records collection...
# Creating document 4304.json in hts_records collection...
# Creating document 4401.json in hts_records collection...
# Creating document 4402.json in hts_records collection...
# Creating document 4403.json in hts_records collection...
# Creating document 4404.json in hts_records collection...
# Creating document 4405.json in hts_records collection...
# Creating document 4406.json in hts_records collection...
# Creating document 4407.json in hts_records collection...
# Creating document 4408.json in hts_records collection...
# Creating document 4409.json in hts_records collection...
# Creating document 4410.json in hts_records collection...
# Creating document 4411.json in hts_records collection...
# Creating document 4412.json in hts_records collection...
# Creating document 4413.json in hts_records collection...
# Creating document 4414.json in hts_records collection...
# Creating document 4415.json in hts_records collection...
# Creating document 4416.json in hts_records collection...
# Creating document 4417.json in hts_records collection...
# Creating document 4418.json in hts_records collection...
# Creating document 4419.json in hts_records collection...
# Creating document 4420.json in hts_records collection...
# Creating document 4421.json in hts_records collection...
# Creating document 4501.json in hts_records collection...
# Creating document 4502.json in hts_records collection...
# Creating document 4503.json in hts_records collection...
# Creating document 4504.json in hts_records collection...
# Creating document 4601.json in hts_records collection...
# Creating document 4602.json in hts_records collection...
# Creating document 4701.json in hts_records collection...
# Creating document 4702.json in hts_records collection...
# Creating document 4703.json in hts_records collection...
# Creating document 4704.json in hts_records collection...
# Creating document 4705.json in hts_records collection...
# Creating document 4706.json in hts_records collection...
# Creating document 4707.json in hts_records collection...
# Creating document 4801.json in hts_records collection...
# Creating document 4802.json in hts_records collection...
# Creating document 4803.json in hts_records collection...
# Creating document 4804.json in hts_records collection...
# Creating document 4805.json in hts_records collection...
# Creating document 4806.json in hts_records collection...
# Creating document 4807.json in hts_records collection...
# Creating document 4808.json in hts_records collection...
# Creating document 4809.json in hts_records collection...
# Creating document 4810.json in hts_records collection...
# Creating document 4811.json in hts_records collection...
# Creating document 4812.json in hts_records collection...
# Creating document 4813.json in hts_records collection...
# Creating document 4814.json in hts_records collection...
# Creating document 4816.json in hts_records collection...
# Creating document 4817.json in hts_records collection...
# Creating document 4818.json in hts_records collection...
# Creating document 4819.json in hts_records collection...
# Creating document 4820.json in hts_records collection...
# Creating document 4821.json in hts_records collection...
# Creating document 4822.json in hts_records collection...
# Creating document 4823.json in hts_records collection...
# Creating document 4901.json in hts_records collection...
# Creating document 4902.json in hts_records collection...
# Creating document 4903.json in hts_records collection...
# Creating document 4904.json in hts_records collection...
# Creating document 4905.json in hts_records collection...
# Creating document 4906.json in hts_records collection...
# Creating document 4907.json in hts_records collection...
# Creating document 4908.json in hts_records collection...
# Creating document 4909.json in hts_records collection...
# Creating document 4910.json in hts_records collection...
# Creating document 4911.json in hts_records collection...
# Creating document 5001.json in hts_records collection...
# Creating document 5002.json in hts_records collection...
# Creating document 5003.json in hts_records collection...
# Creating document 5004.json in hts_records collection...
# Creating document 5005.json in hts_records collection...
# Creating document 5006.json in hts_records collection...
# Creating document 5007.json in hts_records collection...
# Creating document 5101.json in hts_records collection...
# Creating document 5102.json in hts_records collection...
# Creating document 5103.json in hts_records collection...
# Creating document 5104.json in hts_records collection...
# Creating document 5105.json in hts_records collection...
# Creating document 5106.json in hts_records collection...
# Creating document 5107.json in hts_records collection...
# Creating document 5108.json in hts_records collection...
# Creating document 5109.json in hts_records collection...
# Creating document 5110.json in hts_records collection...
# Creating document 5111.json in hts_records collection...
# Creating document 5112.json in hts_records collection...
# Creating document 5113.json in hts_records collection...
# Creating document 5201.json in hts_records collection...
# Creating document 5202.json in hts_records collection...
# Creating document 5203.json in hts_records collection...
# Creating document 5204.json in hts_records collection...
# Creating document 5205.json in hts_records collection...
# Creating document 5206.json in hts_records collection...
# Creating document 5207.json in hts_records collection...
# Creating document 5208.json in hts_records collection...
# Creating document 5209.json in hts_records collection...
# Creating document 5210.json in hts_records collection...
# Creating document 5211.json in hts_records collection...
# Creating document 5212.json in hts_records collection...
# Creating document 5301.json in hts_records collection...
# Creating document 5302.json in hts_records collection...
# Creating document 5303.json in hts_records collection...
# Creating document 5305.json in hts_records collection...
# Creating document 5306.json in hts_records collection...
# Creating document 5307.json in hts_records collection...
# Creating document 5308.json in hts_records collection...
# Creating document 5309.json in hts_records collection...
# Creating document 5310.json in hts_records collection...
# Creating document 5311.json in hts_records collection...
# Creating document 5401.json in hts_records collection...
# Creating document 5402.json in hts_records collection...
# Creating document 5403.json in hts_records collection...
# Creating document 5404.json in hts_records collection...
# Creating document 5405.json in hts_records collection...
# Creating document 5406.json in hts_records collection...
# Creating document 5407.json in hts_records collection...
# Creating document 5408.json in hts_records collection...
# Creating document 5501.json in hts_records collection...
# Creating document 5502.json in hts_records collection...
# Creating document 5503.json in hts_records collection...
# Creating document 5504.json in hts_records collection...
# Creating document 5505.json in hts_records collection...
# Creating document 5506.json in hts_records collection...
# Creating document 5507.json in hts_records collection...
# Creating document 5508.json in hts_records collection...
# Creating document 5509.json in hts_records collection...
# Creating document 5510.json in hts_records collection...
# Creating document 5511.json in hts_records collection...
# Creating document 5512.json in hts_records collection...
# Creating document 5513.json in hts_records collection...
# Creating document 5514.json in hts_records collection...
# Creating document 5515.json in hts_records collection...
# Creating document 5516.json in hts_records collection...
# Creating document 5601.json in hts_records collection...
# Creating document 5602.json in hts_records collection...
# Creating document 5603.json in hts_records collection...
# Creating document 5604.json in hts_records collection...
# Creating document 5605.json in hts_records collection...
# Creating document 5606.json in hts_records collection...
# Creating document 5607.json in hts_records collection...
# Creating document 5608.json in hts_records collection...
# Creating document 5609.json in hts_records collection...
# Creating document 5701.json in hts_records collection...
# Creating document 5702.json in hts_records collection...
# Creating document 5703.json in hts_records collection...
# Creating document 5704.json in hts_records collection...
# Creating document 5705.json in hts_records collection...
# Creating document 5801.json in hts_records collection...
# Creating document 5802.json in hts_records collection...
# Creating document 5803.json in hts_records collection...
# Creating document 5804.json in hts_records collection...
# Creating document 5805.json in hts_records collection...
# Creating document 5806.json in hts_records collection...
# Creating document 5807.json in hts_records collection...
# Creating document 5808.json in hts_records collection...
# Creating document 5809.json in hts_records collection...
# Creating document 5810.json in hts_records collection...
# Creating document 5811.json in hts_records collection...
# Creating document 5901.json in hts_records collection...
# Creating document 5902.json in hts_records collection...
# Creating document 5903.json in hts_records collection...
# Creating document 5904.json in hts_records collection...
# Creating document 5905.json in hts_records collection...
# Creating document 5906.json in hts_records collection...
# Creating document 5907.json in hts_records collection...
# Creating document 5908.json in hts_records collection...
# Creating document 5909.json in hts_records collection...
# Creating document 5910.json in hts_records collection...
# Creating document 5911.json in hts_records collection...
# Creating document 6001.json in hts_records collection...
# Creating document 6002.json in hts_records collection...
# Creating document 6003.json in hts_records collection...
# Creating document 6004.json in hts_records collection...
# Creating document 6005.json in hts_records collection...
# Creating document 6006.json in hts_records collection...
# Creating document 6101.json in hts_records collection...
# Creating document 6102.json in hts_records collection...
# Creating document 6103.json in hts_records collection...
# Creating document 6104.json in hts_records collection...
# Creating document 6105.json in hts_records collection...
# Creating document 6106.json in hts_records collection...
# Creating document 6107.json in hts_records collection...
# Creating document 6108.json in hts_records collection...
# Creating document 6109.json in hts_records collection...
# Creating document 6110.json in hts_records collection...
# Creating document 6111.json in hts_records collection...
# Creating document 6112.json in hts_records collection...
# Creating document 6113.json in hts_records collection...
# Creating document 6114.json in hts_records collection...
# Creating document 6115.json in hts_records collection...
# Creating document 6116.json in hts_records collection...
# Creating document 6117.json in hts_records collection...
# Creating document 6201.json in hts_records collection...
# Creating document 6202.json in hts_records collection...
# Creating document 6203.json in hts_records collection...
# Creating document 6204.json in hts_records collection...
# Creating document 6205.json in hts_records collection...
# Creating document 6206.json in hts_records collection...
# Creating document 6207.json in hts_records collection...
# Creating document 6208.json in hts_records collection...
# Creating document 6209.json in hts_records collection...
# Creating document 6210.json in hts_records collection...
# Creating document 6211.json in hts_records collection...
# Creating document 6212.json in hts_records collection...
# Creating document 6213.json in hts_records collection...
# Creating document 6214.json in hts_records collection...
# Creating document 6215.json in hts_records collection...
# Creating document 6216.json in hts_records collection...
# Creating document 6217.json in hts_records collection...
# Creating document 6301.json in hts_records collection...
# Creating document 6302.json in hts_records collection...
# Creating document 6303.json in hts_records collection...
# Creating document 6304.json in hts_records collection...
# Creating document 6305.json in hts_records collection...
# Creating document 6306.json in hts_records collection...
# Creating document 6307.json in hts_records collection...
# Creating document 6308.json in hts_records collection...
# Creating document 6309.json in hts_records collection...
# Creating document 6310.json in hts_records collection...
# Creating document 6401.json in hts_records collection...
# Creating document 6402.json in hts_records collection...
# Creating document 6403.json in hts_records collection...
# Creating document 6404.json in hts_records collection...
# Creating document 6405.json in hts_records collection...
# Creating document 6406.json in hts_records collection...
# Creating document 6501.json in hts_records collection...
# Creating document 6502.json in hts_records collection...
# Creating document 6504.json in hts_records collection...
# Creating document 6505.json in hts_records collection...
# Creating document 6506.json in hts_records collection...
# Creating document 6507.json in hts_records collection...
# Creating document 6601.json in hts_records collection...
# Creating document 6602.json in hts_records collection...
# Creating document 6603.json in hts_records collection...
# Creating document 6701.json in hts_records collection...
# Creating document 6702.json in hts_records collection...
# Creating document 6703.json in hts_records collection...
# Creating document 6704.json in hts_records collection...
# Creating document 6801.json in hts_records collection...
# Creating document 6802.json in hts_records collection...
# Creating document 6803.json in hts_records collection...
# Creating document 6804.json in hts_records collection...
# Creating document 6805.json in hts_records collection...
# Creating document 6806.json in hts_records collection...
# Creating document 6807.json in hts_records collection...
# Creating document 6808.json in hts_records collection...
# Creating document 6809.json in hts_records collection...
# Creating document 6810.json in hts_records collection...
# Creating document 6811.json in hts_records collection...
# Creating document 6812.json in hts_records collection...
# Creating document 6813.json in hts_records collection...
# Creating document 6814.json in hts_records collection...
# Creating document 6815.json in hts_records collection...
# Creating document 6901.json in hts_records collection...
# Creating document 6902.json in hts_records collection...
# Creating document 6903.json in hts_records collection...
# Creating document 6904.json in hts_records collection...
# Creating document 6905.json in hts_records collection...
# Creating document 6906.json in hts_records collection...
# Creating document 6907.json in hts_records collection...
# Creating document 6909.json in hts_records collection...
# Creating document 6910.json in hts_records collection...
# Creating document 6911.json in hts_records collection...
# Creating document 6912.json in hts_records collection...
# Creating document 6913.json in hts_records collection...
# Creating document 6914.json in hts_records collection...
# Creating document 7001.json in hts_records collection...
# Creating document 7002.json in hts_records collection...
# Creating document 7003.json in hts_records collection...
# Creating document 7004.json in hts_records collection...
# Creating document 7005.json in hts_records collection...
# Creating document 7006.json in hts_records collection...
# Creating document 7007.json in hts_records collection...
# Creating document 7008.json in hts_records collection...
# Creating document 7009.json in hts_records collection...
# Creating document 7010.json in hts_records collection...
# Creating document 7011.json in hts_records collection...
# Creating document 7013.json in hts_records collection...
# Creating document 7014.json in hts_records collection...
# Creating document 7015.json in hts_records collection...
# Creating document 7016.json in hts_records collection...
# Creating document 7017.json in hts_records collection...
# Creating document 7018.json in hts_records collection...
# Creating document 7019.json in hts_records collection...
# Creating document 7020.json in hts_records collection...
# Creating document 7101.json in hts_records collection...
# Creating document 7102.json in hts_records collection...
# Creating document 7103.json in hts_records collection...
# Creating document 7104.json in hts_records collection...
# Creating document 7105.json in hts_records collection...
# Creating document 7106.json in hts_records collection...
# Creating document 7107.json in hts_records collection...
# Creating document 7108.json in hts_records collection...
# Creating document 7109.json in hts_records collection...
# Creating document 7110.json in hts_records collection...
# Creating document 7111.json in hts_records collection...
# Creating document 7112.json in hts_records collection...
# Creating document 7113.json in hts_records collection...
# Creating document 7114.json in hts_records collection...
# Creating document 7115.json in hts_records collection...
# Creating document 7116.json in hts_records collection...
# Creating document 7117.json in hts_records collection...
# Creating document 7118.json in hts_records collection...
# Creating document 7201.json in hts_records collection...
# Creating document 7202.json in hts_records collection...
# Creating document 7203.json in hts_records collection...
# Creating document 7204.json in hts_records collection...
# Creating document 7205.json in hts_records collection...
# Creating document 7206.json in hts_records collection...
# Creating document 7207.json in hts_records collection...
# Creating document 7208.json in hts_records collection...
# Creating document 7209.json in hts_records collection...
# Creating document 7210.json in hts_records collection...
# Creating document 7211.json in hts_records collection...
# Creating document 7212.json in hts_records collection...
# Creating document 7213.json in hts_records collection...
# Creating document 7214.json in hts_records collection...
# Creating document 7215.json in hts_records collection...
# Creating document 7216.json in hts_records collection...
# Creating document 7217.json in hts_records collection...
# Creating document 7218.json in hts_records collection...
# Creating document 7219.json in hts_records collection...
# Creating document 7220.json in hts_records collection...
# Creating document 7221.json in hts_records collection...
# Creating document 7222.json in hts_records collection...
# Creating document 7223.json in hts_records collection...
# Creating document 7224.json in hts_records collection...
# Creating document 7225.json in hts_records collection...
# Creating document 7226.json in hts_records collection...
# Creating document 7227.json in hts_records collection...
# Creating document 7228.json in hts_records collection...
# Creating document 7229.json in hts_records collection...
# Creating document 7301.json in hts_records collection...
# Creating document 7302.json in hts_records collection...
# Creating document 7303.json in hts_records collection...
# ...
# Creating document for <295kg> in string_dict collection...
# Creating document for <315kg> in string_dict collection...
# Creating document for <335kg> in string_dict collection...
# Creating document for <190kg> in string_dict collection...
# Creating document for <290kg> in string_dict collection...
# Creating document for <cottage> in string_dict collection...
# Creating document for <12023080> in string_dict collection...
# Creating document for <12024180> in string_dict collection...
# Creating document for <12024220> in string_dict collection...
# Creating document for <12024290> in string_dict collection...
# Creating document for <20081146> in string_dict collection...
# Creating document for <5¢kg> in string_dict collection...
# Creating document for <19019054> in string_dict collection...
# Creating document for <105¢kg> in string_dict collection...
# Creating document for <20081115> in string_dict collection...
# Creating document for <30¢liter> in string_dict collection...
# Creating document for <50¢liter> in string_dict collection...
# Creating document for <70¢liter> in string_dict collection...
# Creating document for <52010018> in string_dict collection...
# Creating document for <52010028> in string_dict collection...
# Creating document for <52010038> in string_dict collection...
# Creating document for <52010080> in string_dict collection...
# Creating document for <52029930> in string_dict collection...
# Creating document for <320kg> in string_dict collection...
# Creating document for <420kg> in string_dict collection...
# Creating document for <520kg> in string_dict collection...
# Creating document for <620kg> in string_dict collection...
# Creating document for <720kg> in string_dict collection...
# Creating document for <52030030> in string_dict collection...
# Creating document for <israel> in string_dict collection...
# Creating document for <20081161> in string_dict collection...
# Creating document for <07122020> in string_dict collection...
# Creating document for <07122040> in string_dict collection...
# Creating document for <1925¢kg> in string_dict collection...
# Creating document for <308¢kg> in string_dict collection...
# Creating document for <462¢kg> in string_dict collection...
# Creating document for <693¢kg> in string_dict collection...
# Creating document for <315¢kg> in string_dict collection...
# Creating document for <504¢kg> in string_dict collection...
# Creating document for <756¢kg> in string_dict collection...
# Creating document for <1134kg> in string_dict collection...
# Creating document for <07129040> in string_dict collection...
# Creating document for <1325¢kg> in string_dict collection...
# Creating document for <212¢kg> in string_dict collection...
# Creating document for <318¢kg> in string_dict collection...
# Creating document for <477¢kg> in string_dict collection...
# Creating document for <12¢kg> in string_dict collection...
# Creating document for <192¢kg> in string_dict collection...
# Creating document for <288¢kg> in string_dict collection...
# Creating document for <432¢kg> in string_dict collection...
# Creating document for <12b> in string_dict collection...
# Creating document for <12c> in string_dict collection...
# Creating document for <20021000> in string_dict collection...
# Creating document for <20029080> in string_dict collection...
# Creating document for <13¢kg> in string_dict collection...
# Creating document for <208¢kg> in string_dict collection...
# Creating document for <312¢kg> in string_dict collection...
# Creating document for <468¢kg> in string_dict collection...
# Creating document for <1075¢kg> in string_dict collection...
# Creating document for <172¢kg> in string_dict collection...
# Creating document for <258¢kg> in string_dict collection...
# Creating document for <387¢kg> in string_dict collection...
# Creating document for <16¢kg> in string_dict collection...
# Creating document for <256¢kg> in string_dict collection...
# Creating document for <384¢kg> in string_dict collection...
# Creating document for <576¢kg> in string_dict collection...
# Creating document for <14¢kg> in string_dict collection...
# Creating document for <224¢kg> in string_dict collection...
# Creating document for <336¢kg> in string_dict collection...
# Creating document for <115¢kg> in string_dict collection...
# Creating document for <184¢kg> in string_dict collection...
# Creating document for <276¢kg> in string_dict collection...
# Creating document for <414¢kg> in string_dict collection...
# Creating document for <775¢kg> in string_dict collection...
# Creating document for <124¢kg> in string_dict collection...
# Creating document for <186¢kg> in string_dict collection...
# Creating document for <279¢kg> in string_dict collection...
# Creating document for <1725¢kg> in string_dict collection...
# Creating document for <621¢kg> in string_dict collection...
# Creating document for <21032040> in string_dict collection...
# Creating document for <21¢kg> in string_dict collection...
# Creating document for <235¢kg> in string_dict collection...
# Creating document for <376¢kg> in string_dict collection...
# Creating document for <564¢kg> in string_dict collection...
# Creating document for <846¢kg> in string_dict collection...
# Creating document for <24011065> in string_dict collection...
# Creating document for <24012035> in string_dict collection...
# Creating document for <24012087> in string_dict collection...
# Creating document for <24013070> in string_dict collection...
# Creating document for <24031990> in string_dict collection...
# Creating document for <24039147> in string_dict collection...
# Creating document for <24039990> in string_dict collection...
# Creating document for <20056000> in string_dict collection...
# Creating document for <3975¢kg> in string_dict collection...
# Creating document for <636¢kg> in string_dict collection...
# Creating document for <954¢kg> in string_dict collection...
# Creating document for <1431kg> in string_dict collection...
# Creating document for <20057060> in string_dict collection...
# Creating document for <4025¢kg> in string_dict collection...
# Creating document for <644¢kg> in string_dict collection...
# Creating document for <966¢kg> in string_dict collection...
# Creating document for <1449kg> in string_dict collection...
# Creating document for <39¢kg> in string_dict collection...
# Creating document for <624¢kg> in string_dict collection...
# Creating document for <936¢kg> in string_dict collection...
# Creating document for <1404kg> in string_dict collection...
# Creating document for <4475¢kg> in string_dict collection...
# Creating document for <716¢kg> in string_dict collection...
# Creating document for <1074kg> in string_dict collection...
# Creating document for <1611kg> in string_dict collection...
# Creating document for <2425¢kg> in string_dict collection...
# Creating document for <388¢kg> in string_dict collection...
# Creating document for <582¢kg> in string_dict collection...
# Creating document for <873¢kg> in string_dict collection...
# Creating document for <375¢kg> in string_dict collection...
# Creating document for <20084000> in string_dict collection...
# Creating document for <1625¢kg> in string_dict collection...
# Creating document for <26¢kg> in string_dict collection...
# Creating document for <585¢kg> in string_dict collection...
# Creating document for <1575¢kg> in string_dict collection...
# Creating document for <252¢kg> in string_dict collection...
# Creating document for <378¢kg> in string_dict collection...
# Creating document for <567¢kg> in string_dict collection...
# Creating document for <20085040> in string_dict collection...
# Creating document for <245¢kg> in string_dict collection...
# Creating document for <392¢kg> in string_dict collection...
# Creating document for <588¢kg> in string_dict collection...
# Creating document for <882¢kg> in string_dict collection...
# Creating document for <20087010> in string_dict collection...
# Creating document for <20087020> in string_dict collection...
# Creating document for <145¢kg> in string_dict collection...
# Creating document for <232¢kg> in string_dict collection...
# Creating document for <348¢kg> in string_dict collection...
# Creating document for <522¢kg> in string_dict collection...
# Creating document for <1375¢kg> in string_dict collection...
# Creating document for <22¢kg> in string_dict collection...
# Creating document for <33¢kg> in string_dict collection...
# Creating document for <495¢kg> in string_dict collection...
# Creating document for <20089790> in string_dict collection...
# Creating document for <2075¢kg> in string_dict collection...
# Creating document for <332¢kg> in string_dict collection...
# Creating document for <498¢kg> in string_dict collection...
# Creating document for <747¢kg> in string_dict collection...
# Creating document for <1875¢kg> in string_dict collection...
# Creating document for <675¢kg> in string_dict collection...
# Creating document for <3025¢kg> in string_dict collection...
# Creating document for <484¢kg> in string_dict collection...
# Creating document for <726¢kg> in string_dict collection...
# Creating document for <1089kg> in string_dict collection...
# Creating document for <32¢kg> in string_dict collection...
# Creating document for <48¢kg> in string_dict collection...
# Creating document for <72¢kg> in string_dict collection...
# Creating document for <20091100> in string_dict collection...
# Creating document for <575¢liter> in string_dict collection...
# Creating document for <92¢liter> in string_dict collection...
# Creating document for <138¢liter> in string_dict collection...
# Creating document for <207¢liter> in string_dict collection...
# Creating document for <55¢liter> in string_dict collection...
# Creating document for <88¢liter> in string_dict collection...
# Creating document for <132¢liter> in string_dict collection...
# Creating document for <198¢liter> in string_dict collection...
# Creating document for <5¢liter> in string_dict collection...
# Creating document for <8¢liter> in string_dict collection...
# Creating document for <12¢liter> in string_dict collection...
# Creating document for <18¢liter> in string_dict collection...
# Creating document for <20091245> in string_dict collection...
# Creating document for <1225¢liter> in string_dict collection...
# Creating document for <196¢liter> in string_dict collection...
# Creating document for <294¢liter> in string_dict collection...
# Creating document for <441¢liter> in string_dict collection...
# Creating document for <20091900> in string_dict collection...
# Creating document for <04069033> in string_dict collection...
# Creating document for <08044000> in string_dict collection...
# Creating document for <1025¢kg> in string_dict collection...
# Creating document for <164¢kg> in string_dict collection...
# Creating document for <246¢kg> in string_dict collection...
# Creating document for <369¢kg> in string_dict collection...
# Creating document for <369kg> in string_dict collection...
# Creating document for <225¢kg> in string_dict collection...
# Creating document for <36¢kg> in string_dict collection...
# Creating document for <54¢kg> in string_dict collection...
# Creating document for <81¢kg> in string_dict collection...
# Creating document for <8¢kg> in string_dict collection...
# Creating document for <128¢kg> in string_dict collection...
# Creating document for <135¢kg> in string_dict collection...
# Creating document for <216¢kg> in string_dict collection...
# Creating document for <324¢kg> in string_dict collection...
# Creating document for <486¢kg> in string_dict collection...
# Creating document for <575¢liters> in string_dict collection...
# Creating document for <92¢liters> in string_dict collection...
# Creating document for <138¢liters> in string_dict collection...
# Creating document for <207¢liters> in string_dict collection...
# Creating document for <5¢liters> in string_dict collection...
# Creating document for <8¢liters> in string_dict collection...
# Creating document for <12¢liters> in string_dict collection...
# Creating document for <18¢liters> in string_dict collection...
# Creating document for <1225¢liters> in string_dict collection...
# Creating document for <196¢liters> in string_dict collection...
# Creating document for <294¢liters> in string_dict collection...
# Creating document for <441¢liters> in string_dict collection...
# Creating document for <20096100> in string_dict collection...
# Creating document for <14¢liters> in string_dict collection...
# Creating document for <224¢liters> in string_dict collection...
# Creating document for <336¢liters> in string_dict collection...
# Creating document for <504¢liters> in string_dict collection...
# Creating document for <85¢liters> in string_dict collection...
# Creating document for <136¢liters> in string_dict collection...
# Creating document for <204¢liters> in string_dict collection...
# Creating document for <306¢liters> in string_dict collection...
# Creating document for <675¢liters> in string_dict collection...
# Creating document for <108¢liters> in string_dict collection...
# Creating document for <162¢liters> in string_dict collection...
# Creating document for <243¢liters> in string_dict collection...
# Creating document for <20096900> in string_dict collection...
# Creating document for <128¢liters> in string_dict collection...
# Creating document for <192¢liters> in string_dict collection...
# Creating document for <288¢liters> in string_dict collection...
# Creating document for <625¢liters> in string_dict collection...
# Creating document for <10¢liters> in string_dict collection...
# Creating document for <15¢liters> in string_dict collection...
# Creating document for <225¢liters> in string_dict collection...
# Creating document for <el> in string_dict collection...
# Creating document for <salvador> in string_dict collection...
# Creating document for <honduras> in string_dict collection...
# Creating document for <nicaragua> in string_dict collection...
# Creating document for <guatemala> in string_dict collection...
# Creating document for <12024280> in string_dict collection...
# Creating document for <20081135> in string_dict collection...
# Creating document for <20081160> in string_dict collection...
# Creating document for <12a> in string_dict collection...
# Creating document for <13a> in string_dict collection...
# Creating document for <13b> in string_dict collection...
# Creating document for <14a> in string_dict collection...
# Creating document for <14b> in string_dict collection...
# Creating document for <61159560> in string_dict collection...
# Creating document for <61159590> in string_dict collection...
# Creating document for <98220510> in string_dict collection...
# Creating document for <2008> in string_dict collection...
# Creating document for <mastectomy> in string_dict collection...
# Creating document for <61124100> in string_dict collection...
# Creating document for <61124900> in string_dict collection...
# Creating document for <aggre> in string_dict collection...
# Creating document for <16a> in string_dict collection...
# Creating document for <16d> in string_dict collection...
# Creating document for <1806208318063270> in string_dict collection...
# Creating document for <19011060> in string_dict collection...
# Creating document for <24029000> in string_dict collection...
# Creating document for <2403> in string_dict collection...
# Creating document for <61112060> in string_dict collection...
# Creating document for <61113050> in string_dict collection...
# Creating document for <61119050> in string_dict collection...
# Creating document for <currently> in string_dict collection...
# Creating document for <61159400> in string_dict collection...
# Creating document for <61159660> in string_dict collection...
# Creating document for <61159914> in string_dict collection...
# Creating document for <61159919> in string_dict collection...
# Creating document for <61159940> in string_dict collection...
# Creating document for <61159990> in string_dict collection...
# Creating document for <38247101> in string_dict collection...
# Creating document for <84159080> in string_dict collection...
# Creating document for <thissubchapter> in string_dict collection...
# Completed creating string_dict collection!
