# %%
key_words = ["a","about","above","after","again","against","all","am","an","and","any","are","aren't","as","at","be","because","been","before","being","below","between","both","but","by","can't","cannot","could","couldn't","did","didn't","do","does","doesn't","doing","don't","down","during","each","few","for","from","further","had","hadn't","has","hasn't","have","haven't","having","he","he'd","he'll","he's","her","here","here's","hers","herself","him","himself","his","how","how's","i","i'd","i'll","i'm","i've","if","in","into","is","isn't","it","it's","its","itself","let's","me","more","most","mustn't","my","myself","no","nor","not","of","off","on","once","only","or","other","ought","our","ours","ourselves","out","over","own","same","shan't","she","she'd","she'll","she's","should","shouldn't","so","some","such","than","that","that's","the","their","theirs","them","themselves","then","there","there's","these","they","they'd","they'll","they're","they've","this","those","through","to","too","under","until","up","very","was","wasn't","we","we'd","we'll","we're","we've","were","weren't","what","what's","when","when's","where","where's","which","while","who","who's","whom","why","why's","with","won't","would","wouldn't","you","you'd","you'll","you're","you've","your","yours","yourself","yourselves"]

punctuation_pattern = r'[!\"#$%&\'()*+,-./:;<=>?@\[\]\^_`{|}~—]'

# %%
import json
import os
import re

#REPEATED FROM chapterOrganizer file (remember to consolidate this method)
def checkKeyWords(string: str):
    """Checks against the keywords list for any matches in the string input

    Args:
        string (str): String that will be checked

    Returns:
        bool: True if the string does not coincide with the list, False if there is a match
    """

    for keyword in key_words:
        match = re.search(rf'^{keyword}$', string=string)
        if(match):
            return False
    
    return True

# %%
def queryStringProcessing(string: str):
    """Function to process and normalize the query string in order to get an array of strings using the checkKeyWords method to remove all banned keywords from the query and punctuation signs

    Args:
        string (str): Query string input

    Returns:
        list: List of strings in the original input after processing with no punctuation or banned keywords
    """

    list_string = string.split(' ')
    result_string = []

    for st in list_string:

        normal_string = re.sub(punctuation_pattern, '', st.lower())
        if(checkKeyWords(normal_string)):
            
            result_string.append(normal_string) 

    
    return result_string



queryStringProcessing('Hola, soy Ricardo, then, for')
# Out:
# ['hola', 'soy', 'ricardo']

# %%
def mapStringQuery(query: list):
    """Function that takes the list query preprocessed in the queryStringProcessing() and processes the list against the string_dict file elements to gather the information for the queryMap object.

    Args:
        query (list): Processed string query input as a list with the banned words removed

    Returns:
        dict: queryMap dictionary comprised of a map with all relevant sections that coincided with a result and an array of objects with the necessary info for each result - section - string.
    """
    queryMap = {
        'map': [],
        'query': []
    }

    with open('../db_hts/temp/NEW_test_string_dict/string_dict.json', 'r') as data:
        string_dict = json.load(data)

        for string in query:

            if string in string_dict:
                queryMap['map'].extend(string_dict[string])
                queryMap['query'].append(
                    {
                        'keyword': string,
                        'sections': string_dict[string]
                    }
                )

    #REMOVES THE DUPLICATES IN THE LIST
    queryMap['map'] = list(dict.fromkeys(queryMap['map']))

    return queryMap

def mapHierarchy(queryMap: dict):
    """Function that processes the queryMap object to generate a new object with the coincidences and sections relevant for the final display of the query

    Args:
        queryMap (dict): queryMap dictionary containing the initial result of the query

    Returns:
        dict: Dictionary object with keys as section numbers and value of a coincidence and keyword keys that represent the keywords present in each section with the respective number of coincidences present
    """
    mapCoincidences = {}

    for query in queryMap['query']:
        
        for section in queryMap['map']:

            if(section in query['sections']):

                if(section in mapCoincidences.keys()):
                    mapCoincidences[section]['keyword'].append(query['keyword'])
                    mapCoincidences[section]['coincidence'] =  mapCoincidences[section]['coincidence'] + 1
                else:
                    mapCoincidences[section] = {
                        'coincidence': 1,
                        'keyword': [query['keyword']]
                    }
    
    return mapCoincidences

# %%
def processCoincidences(coincidences: dict):
    """Function that takes the mapHierarchy object and processes that object agains the database information for each hts Section located in the JSON files by HTS header.

    Args:
        coincidences (dict): mapHierarchy object returned by that function that shows the initial coincidences of the search query and their corresponding HTS sections

    Returns:
        list: Returns a final_result list with dictionary objects containing the final queried values both from the initial query coincidences and the HTS database
    """
    final_result = []

    for key in coincidences:
        with open(f'../db_hts/temp/NEW_test_files/{key}.json') as file:

            json_file = json.load(file)

            final_result.append(traverseFile(json_file, coincidences[key]['keyword']))

    return final_result
    


def traverseFile(file: dict, list_string: list):
    """Helper function that provides the final result agains the HTS JSON database query.

    Args:
        file (dict): Dictionary representing the JSON file loaded with the HTS chapters and subchapter information in that file
        list_string (list): List of query keywords already processed that pertain to that specific file

    Returns:
        dict: Final result of the query the JSON database, with all keyword final coincidence and repeat values, alongside all the raw data extracted from each item of the original file
    """

    result = []
    navigator = {
        'counter': 0,
        'continue': False,
        'currenthts': ''
    }
    
    for item in file:
        
        #This checks if the navigator is currently activated to reiterate the same index of the result and add additional data, or continue to create new index in the result
        if(navigator['continue'] == False):

            temp_result = traverseDescription(list_string, item['description'].lower())

            #Checks if the list_string has matches in the item['description'] string
            if(temp_result['match']):
                result.append(temp_result)
                result[navigator['counter']]['matchedInformation']['data'].append(item)
                
                #Checks for the current value of the navigator, if the loop will create a new result index or use the next elif conditional to add to the original index
                navigator['continue'] = traverseItem(item, item['htsno'], list_string)['go']
                navigator['currenthts'] = item['htsno']
                #Adds one to the counter for the next iteration of the loop in case navigator['continue'] is False
                navigator['counter'] += 1

        #Checks if the result index was previously created and if the navigator process will continue (meaning the ['continue'] key is set to True)
        elif(navigator['continue'] == True):   
            #Adds the new item information 
            temp_navigator = traverseItem(item, navigator['currenthts'], list_string)
            navigator['continue'] = temp_navigator['go']
            if 'additionalstr' in temp_navigator:
                result[navigator['counter']-1]['matchedInformation']['data'].append(item)
                result[navigator['counter']-1]['matchedInformation']['keyword'].extend(temp_navigator['additionalstr'])

        
    return result
    
def traverseDescription(list_string: list, description: str):
    """Function that works to check what values from the list provided are existent in the description string provided from the JSON hts file description section

    Args:
        list_string (list): List of string query
        description (str): Full description string to be checked

    Returns:
        dict: Returns a dictionary with both a matched information key that contains the keywords matched and if the match was successful, and an empty list as the 'data' key for further addition of data outside this function
    """
    result = {
        
        'matchedInformation': {'keyword': [], 'data': []},
        'match': False   
    }

    for string in list_string:
        pattern = rf'[\( ]{string}[\) ,.:]|^{string}[\) ,.:]|[\( ]{string}'
        match_string = re.search(pattern, description)
        if(match_string):
            result['matchedInformation']['keyword'].append(string)
            result['match'] = True
    
    return result


def traverseItem(item: dict, current_pattern: str, list_string: list):
    """Function that further traverses the item object when there is a match in the query string, looking for further matches for both the hts code retrieved and the list_string initial query input and adds any repeated results or new keywords to the data being retrieved

    Args:
        item (dict): item dictionary object from the JSON HTS file being processed
        current_pattern (str): Pattern string HTS number currently being processed
        list_string (list): Original query list of strings being processed

    Returns:
        _type_: Dictionary with either the key 'go' bool that indicates the processs continues and the 'additionalstr' key containing additional keyword matches, or only the key 'go' with False, indicating the process will stop
    """
    final_pattern = rf'^(?! +$){current_pattern}|^$'

    match_hts = re.search(final_pattern, item['htsno'])
    additonal_keywords = []

    if(match_hts):
        for string in list_string:
            pattern = rf'[\( ]{string}[\) ,.:]|^{string}[\) ,.:]|[\( ]{string}'
            match_string = re.search(pattern, item['description'].lower())
            if(match_string):
                additonal_keywords.append(string)
        return {
            'go': True,
            'additionalstr': additonal_keywords
        }
    else:
        return {
            'go': False,
        }

# %%
query_string = queryStringProcessing('Live horses, asses mammals')

print(query_string)

queryMap = mapStringQuery(query_string)

coincidence = mapHierarchy(queryMap)

coincidence
# Out:
# ['live', 'horses', 'asses', 'mammals']
# {'0105': {'coincidence': 1, 'keyword': ['live']},
#  '0309': {'coincidence': 1, 'keyword': ['live']},
#  '0102': {'coincidence': 1, 'keyword': ['live']},
#  '0104': {'coincidence': 1, 'keyword': ['live']},
#  '0307': {'coincidence': 1, 'keyword': ['live']},
#  '0103': {'coincidence': 1, 'keyword': ['live']},
#  '0308': {'coincidence': 1, 'keyword': ['live']},
#  '0106': {'coincidence': 2, 'keyword': ['live', 'mammals']},
#  '0301': {'coincidence': 1, 'keyword': ['live']},
#  '0306': {'coincidence': 1, 'keyword': ['live']},
#  '0101': {'coincidence': 3, 'keyword': ['live', 'horses', 'asses']},
#  '0602': {'coincidence': 1, 'keyword': ['live']},
#  '0206': {'coincidence': 2, 'keyword': ['horses', 'asses']},
#  '9804': {'coincidence': 1, 'keyword': ['horses']},
#  '0205': {'coincidence': 2, 'keyword': ['horses', 'asses']},
#  '0208': {'coincidence': 1, 'keyword': ['mammals']},
#  '0210': {'coincidence': 1, 'keyword': ['mammals']},
#  '1504': {'coincidence': 1, 'keyword': ['mammals']},
#  '9902': {'coincidence': 1, 'keyword': ['mammals']}}

# %%
final_result = processCoincidences(coincidence)

final_result
# Out:
# [[{'matchedInformation': {'keyword': ['live'],
#     'data': [{'htsno': '0105',
#       'indent': 0,
#       'description': 'Live poultry of the following kinds: Chickens, ducks, geese, turkeys and guineas:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': '',
#       'additionalDuties': '',
#       'addiitionalDuties': None},
#      {'htsno': '0105.11.00',
#       'indent': 2,
#       'description': 'Chickens | Weighing not more than 185 g:',
#       'superior': None,
#       'units': [],
#       'general': '0.9¢ each',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E, IL,JO,KR, MA,OM, P,PA,PE,S,SG)',
#       'other': '4¢ each',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.11.00.10',
#       'indent': 4,
#       'description': 'Layer-type (egg-type) | Breeding stock, whether or not purebred:',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.11.00.20',
#       'indent': 4,
#       'description': 'Broiler-type (meat-type) | Breeding stock, whether or not purebred:',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.11.00.40',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.12.00.00',
#       'indent': 2,
#       'description': 'Turkeys',
#       'superior': None,
#       'units': ['No.'],
#       'general': '0.9¢ each',
#       'special': 'Free (A+,AU,BH, CL,CO,D,E, IL,JO,KR,MA,OM,P,PA, PE,S,SG)',
#       'other': '4¢ each',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.13.00.00',
#       'indent': 2,
#       'description': 'Ducks',
#       'superior': None,
#       'units': ['No.'],
#       'general': '0.9¢ each',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E, IL,JO,KR,MA,OM,P,PA,PE,S, SG)',
#       'other': '4¢ each',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.14.00.00',
#       'indent': 2,
#       'description': 'Geese',
#       'superior': None,
#       'units': ['No.'],
#       'general': '0.9¢ each',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA, OM,P,PA,PE,S,SG)',
#       'other': '4¢ each',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.15.00.00',
#       'indent': 2,
#       'description': 'Guinea fowls',
#       'superior': None,
#       'units': ['No.'],
#       'general': '0.9¢ each',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA, OM,P,PA,PE,S,SG)',
#       'other': '4¢ each',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.94.00.00',
#       'indent': 2,
#       'description': 'Chickens | Other:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '2¢/kg',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA, OM,P,PA,PE,S,SG)',
#       'other': '17.6¢/kg',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0105.99.00.00',
#       'indent': 2,
#       'description': 'Other | Other:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '2¢/kg',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA, OM,P,PA,PE,S,SG)',
#       'other': '17.6¢/kg',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['live'],
#     'data': [{'htsno': '0309.90.20.00',
#       'indent': 3,
#       'description': 'Live, fresh, or chilled',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True},
#   {'matchedInformation': {'keyword': ['live'],
#     'data': [{'htsno': '0309.90.40',
#       'indent': 3,
#       'description': 'Live, fresh or chilled | Of molluscs:',
#       'superior': None,
#       'units': [''],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0309.90.40.30',
#       'indent': 4,
#       'description': 'Conch',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0309.90.40.90',
#       'indent': 4,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['live'],
#     'data': [{'htsno': '0102',
#       'indent': 0,
#       'description': 'Live bovine animals:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': '',
#       'additionalDuties': '',
#       'addiitionalDuties': None},
#      {'htsno': '0102.21.00',
#       'indent': 2,
#       'description': 'Purebred breeding animals | Cattle:',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.21.00.10',
#       'indent': 4,
#       'description': 'Male | Dairy:',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.21.00.20',
#       'indent': 4,
#       'description': 'Female | Dairy:',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.21.00.30',
#       'indent': 4,
#       'description': 'Male | Other:',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.21.00.50',
#       'indent': 4,
#       'description': 'Female | Other:',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29',
#       'indent': 2,
#       'description': 'Other:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': '',
#       'additionalDuties': '',
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.20',
#       'indent': 3,
#       'description': 'Cows imported specially for dairy purposes',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': '6.6¢/kg',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.20.11',
#       'indent': 4,
#       'description': 'Weighing less than 90 kg each',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.20.12',
#       'indent': 4,
#       'description': 'Weighing 90 kg or more each',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': [],
#       'general': '1¢/kg',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '5.5¢/kg',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.24',
#       'indent': 5,
#       'description': 'Male | Weighing less than 90 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.28',
#       'indent': 5,
#       'description': 'Female | Weighing less than 90 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.34',
#       'indent': 5,
#       'description': 'Male | Weighing 90 kg or more but less than 200 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.38',
#       'indent': 5,
#       'description': 'Female | Weighing 90 kg or more but less than 200 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.54',
#       'indent': 5,
#       'description': 'Male | Weighing 200 kg or more but less than 320 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.58',
#       'indent': 5,
#       'description': 'Female | Weighing 200 kg or more but less than 320 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.62',
#       'indent': 6,
#       'description': 'Steers | For immediate slaughter:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.64',
#       'indent': 6,
#       'description': 'Bulls | For immediate slaughter:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.66',
#       'indent': 6,
#       'description': 'Cows | For immediate slaughter:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.68',
#       'indent': 6,
#       'description': 'Heifers | For immediate slaughter:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.72',
#       'indent': 6,
#       'description': 'Male | For breeding:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.74',
#       'indent': 6,
#       'description': 'Female | For breeding:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.82',
#       'indent': 6,
#       'description': 'Male | Other:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.29.40.84',
#       'indent': 6,
#       'description': 'Female | Other:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.31.00',
#       'indent': 2,
#       'description': 'Purebred breeding animals | Buffalo:',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.31.00.10',
#       'indent': 3,
#       'description': 'Male',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.31.00.20',
#       'indent': 3,
#       'description': 'Female',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00',
#       'indent': 2,
#       'description': 'Other',
#       'superior': None,
#       'units': [],
#       'general': '1¢/kg',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '5.5¢/kg',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.10',
#       'indent': 3,
#       'description': 'Bison',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.24',
#       'indent': 5,
#       'description': 'Male | Weighing less than 90 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.28',
#       'indent': 5,
#       'description': 'Female | Weighing less than 90 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.34',
#       'indent': 5,
#       'description': 'Male | Weighing 90 kg or more but less than 200 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.38',
#       'indent': 5,
#       'description': 'Female | Weighing 90 kg or more but less than 200 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.54',
#       'indent': 5,
#       'description': 'Male | Weighing 200 kg or more but less than 320 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.58',
#       'indent': 5,
#       'description': 'Female | Weighing 200 kg or more but less than 320 kg each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.61',
#       'indent': 5,
#       'description': 'For immediate slaughter | Weighing 320 kg or more each:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.72',
#       'indent': 6,
#       'description': 'Male | For breeding:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.74',
#       'indent': 6,
#       'description': 'Female | For breeding:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.82',
#       'indent': 6,
#       'description': 'Male | Other:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.39.00.84',
#       'indent': 6,
#       'description': 'Female | Other:',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0102.90.00.00',
#       'indent': 1,
#       'description': 'Other',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': '1¢/kg',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '5.5¢/kg',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['live'],
#     'data': [{'htsno': '0104',
#       'indent': 0,
#       'description': 'Live sheep and goats:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': '',
#       'additionalDuties': '',
#       'addiitionalDuties': None},
#      {'htsno': '0104.10.00.00',
#       'indent': 1,
#       'description': 'Sheep',
#       'superior': None,
#       'units': ['No.', 'kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '$3/head',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0104.20.00.00',
#       'indent': 1,
#       'description': 'Goats',
#       'superior': None,
#       'units': ['No.'],
#       'general': '68¢/head',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E, IL,JO,KR,MA,OM,P,PA, PE,S,SG)',
#       'other': '$3/head',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['live',
#      'live',
#      'live',
#      'live',
#      'live',
#      'live',
#      'live',
#      'live',
#      'live',
#      'live'],
#     'data': [{'htsno': '0307',
#       'indent': 0,
#       'description': 'Molluscs, whether in shell or not, live, fresh, chilled, frozen, dried, salted or in brine; smoked molluscs, whether in shell or not, whether or not cooked before or during the smoking process:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.11.00',
#       'indent': 2,
#       'description': 'Live, fresh or chilled | Oysters:',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.11.00.20',
#       'indent': 3,
#       'description': 'Seed oysters',
#       'superior': None,
#       'units': ['liters', 'kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.11.00.60',
#       'indent': 4,
#       'description': 'Farmed | Other:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.11.00.80',
#       'indent': 4,
#       'description': 'Other | Other:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.12.00',
#       'indent': 2,
#       'description': 'Frozen',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.12.00.60',
#       'indent': 3,
#       'description': 'Farmed',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.12.00.80',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.19.01',
#       'indent': 2,
#       'description': 'Other',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.19.01.60',
#       'indent': 3,
#       'description': 'Farmed',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.19.01.80',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.21.00.00',
#       'indent': 2,
#       'description': 'Live, fresh or chilled | Scallops and other molluscs of the family <i>Pectinidae</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.22.00.00',
#       'indent': 2,
#       'description': 'Frozen | Scallops and other molluscs of the family <i>Pectinidae</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.29.01.00',
#       'indent': 2,
#       'description': 'Other | Scallops and other molluscs of the family <i>Pectinidae</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.31.00',
#       'indent': 2,
#       'description': 'Live, fresh or chilled | Mussels (<i>Mytilus spp., Perna spp.</i>):',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.31.00.10',
#       'indent': 3,
#       'description': 'Farmed',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.31.00.90',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.32.00.00',
#       'indent': 2,
#       'description': 'Frozen',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.39.01.00',
#       'indent': 2,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.42.00',
#       'indent': 2,
#       'description': 'Live, fresh or chilled | Cuttle fish and squid:',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.42.00.20',
#       'indent': 4,
#       'description': 'Loligo | Squid:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.42.00.40',
#       'indent': 4,
#       'description': 'Other | Squid:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.42.00.60',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.43.00',
#       'indent': 2,
#       'description': 'Frozen',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.43.00.10',
#       'indent': 4,
#       'description': 'Fillets | Squid:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.43.00.22',
#       'indent': 6,
#       'description': '<i>Loligo opalescens</i> | Loligo:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.43.00.24',
#       'indent': 6,
#       'description': '<i>Loligo pealei</i> | Loligo:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.43.00.29',
#       'indent': 6,
#       'description': 'Other | Loligo:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.43.00.50',
#       'indent': 5,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.43.00.60',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.49.01',
#       'indent': 2,
#       'description': 'Other',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.49.01.22',
#       'indent': 5,
#       'description': '<i>Loligo opalescens</i> | Loligo:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.49.01.24',
#       'indent': 5,
#       'description': '<i>Loligo pealei</i> | Loligo:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.49.01.29',
#       'indent': 5,
#       'description': 'Other | Loligo:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.49.01.50',
#       'indent': 4,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.49.01.60',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.51.00.00',
#       'indent': 2,
#       'description': 'Live, fresh or chilled | Octopus (<i>Octopus spp.</i>):',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.52.00.00',
#       'indent': 2,
#       'description': 'Frozen | Octopus (<i>Octopus spp.</i>):',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.59.01.00',
#       'indent': 2,
#       'description': 'Other | Octopus (<i>Octopus spp.</i>):',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.60.00.00',
#       'indent': 1,
#       'description': 'Snails, other than sea snails',
#       'superior': None,
#       'units': ['kg'],
#       'general': '5%',
#       'special': 'Free (A*,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '20%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.71.00',
#       'indent': 2,
#       'description': 'Live, fresh or chilled | Clams, cockles and ark shells (families <i>Arcidae, Arcticidae, Cardiidae, Donacidae, Hiatellidae, Mactridae, Mesodesmatidae, Myidae, Semelidae, Solecurtidae, Solenidae, Tridacnidae</i> and <i>Veneridae</i>):',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.71.00.50',
#       'indent': 4,
#       'description': 'Geoduck | Clams:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.71.00.70',
#       'indent': 4,
#       'description': 'Other | Clams:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.71.00.90',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.72.00',
#       'indent': 2,
#       'description': 'Frozen',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.72.00.30',
#       'indent': 4,
#       'description': 'Geoduck | Clams:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.72.00.51',
#       'indent': 4,
#       'description': 'Stimsonʼs | Clams:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.72.00.55',
#       'indent': 4,
#       'description': 'Other | Clams:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.72.00.60',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.79.01',
#       'indent': 2,
#       'description': 'Other',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.79.01.30',
#       'indent': 4,
#       'description': 'Geoduck | Clams:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.79.01.51',
#       'indent': 4,
#       'description': 'Stimsonʼs | Clams:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.79.01.55',
#       'indent': 4,
#       'description': 'Other | Clams:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.79.01.60',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.81.00.00',
#       'indent': 2,
#       'description': 'Live, fresh or chilled abalone (<i>Haliotis spp.)</i> | Abalone (<i>Haliotis spp.</i>) and stromboid conchs (<i>Strombus spp.)</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.82.00.00',
#       'indent': 2,
#       'description': 'Live, fresh or chilled stromboid conchs (<i>Strombus spp.</i>) | Abalone (<i>Haliotis spp.</i>) and stromboid conchs (<i>Strombus spp.)</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.83.00.00',
#       'indent': 2,
#       'description': 'Frozen abalone (<i>Haliotis spp.)</i> | Abalone (<i>Haliotis spp.</i>) and stromboid conchs (<i>Strombus spp.)</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.84.00.00',
#       'indent': 2,
#       'description': 'Frozen stromboid conchs (<i>Strombus spp.</i>) | Abalone (<i>Haliotis spp.</i>) and stromboid conchs (<i>Strombus spp.)</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.87.00.00',
#       'indent': 2,
#       'description': 'Other abalone (<i>Haliotis spp.</i>) | Abalone (<i>Haliotis spp.</i>) and stromboid conchs (<i>Strombus spp.)</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.88.00.00',
#       'indent': 2,
#       'description': 'Other stromboid conchs (<i>Strombus spp.</i>) | Abalone (<i>Haliotis spp.</i>) and stromboid conchs (<i>Strombus spp.)</i>:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.91.03',
#       'indent': 2,
#       'description': 'Live, fresh or chilled | Other:',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.91.03.30',
#       'indent': 3,
#       'description': 'Conch',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.91.03.90',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.92.01',
#       'indent': 2,
#       'description': 'Frozen',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0307.92.01.30',
#       'indent': 3,
#       'description': 'Conch',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
# ...
#       'addiitionalDuties': None},
#      {'htsno': '0602.90.60.10',
#       'indent': 5,
#       'description': 'Trees and shrubs',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0602.90.60.20',
#       'indent': 5,
#       'description': 'Poinsettias',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0602.90.60.90',
#       'indent': 5,
#       'description': 'Other',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0602.90.90',
#       'indent': 4,
#       'description': 'Other',
#       'superior': None,
#       'units': [],
#       'general': '4.8%',
#       'special': 'Free (A*,AU,BH,CL,CO,D,E,IL,JO,JP,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '25%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0602.90.90.10',
#       'indent': 5,
#       'description': 'Trees and shrubs',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0602.90.90.90',
#       'indent': 5,
#       'description': 'Other',
#       'superior': None,
#       'units': ['No.'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['horses', 'asses', 'horses', 'asses'],
#     'data': [{'htsno': '0206',
#       'indent': 0,
#       'description': 'Edible offal of bovine animals, swine, sheep, goats, horses, asses, mules or hinnies, fresh, chilled or frozen:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': '',
#       'additionalDuties': '',
#       'addiitionalDuties': None},
#      {'htsno': '0206.10.00.00',
#       'indent': 1,
#       'description': 'Of bovine animals, fresh or chilled',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.21.00.00',
#       'indent': 2,
#       'description': 'Tongues | Of bovine animals, frozen:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.22.00.00',
#       'indent': 2,
#       'description': 'Livers | Of bovine animals, frozen:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.29.00.00',
#       'indent': 2,
#       'description': 'Other | Of bovine animals, frozen:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.30.00.00',
#       'indent': 1,
#       'description': 'Of swine, fresh or chilled',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.41.00.00',
#       'indent': 2,
#       'description': 'Livers | Of swine, frozen:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.49.00.00',
#       'indent': 2,
#       'description': 'Other | Of swine, frozen:',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.80.00.00',
#       'indent': 1,
#       'description': 'Other, fresh or chilled',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.90.00',
#       'indent': 1,
#       'description': 'Other, frozen',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': '30%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.90.00.20',
#       'indent': 2,
#       'description': 'Of sheep (including lamb)',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '0206.90.00.40',
#       'indent': 2,
#       'description': 'Of goats, horses, asses, mules or hinnies',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['horses'],
#     'data': [{'htsno': '9804.00.35',
#       'indent': 1,
#       'description': 'Automobiles, trailers, aircraft, motorcycles, bicycles, baby carriages, boats, horse-drawn conveyances, horses and similar means of transportation, and the usual equipment accompanying the foregoing; any of the foregoing imported in connection with the arrival of such person and to be used in the United States only for the transportation of such person, his family and guests, and such incidental carriage of articles as may be appropriate to his personal use of the conveyance | Articles imported by or for the account of any person arriving in the United States who is not a returning resident thereof:',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['stat'],
#         'marker': '1',
#         'value': 'See chapter 98 statistical note 1.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['horses', 'asses'],
#     'data': [{'htsno': '0205.00.00.00',
#       'indent': 0,
#       'description': 'Meat of horses, asses, mules or hinnies, fresh, chilled or frozen',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['mammals'],
#     'data': [{'htsno': '0208.40.01.00',
#       'indent': 1,
#       'description': 'Of whales, dolphins and porpoises (mammals of the order Cetacea); of manatees and dugongs (mammals of the order Sirenia); of seals, sea lions and walruses (mammals of the suborder Pinnipedia).',
#       'superior': None,
#       'units': ['kg'],
#       'general': '6.4%',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '20%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['mammals'],
#     'data': [{'htsno': '0210.92.01.00',
#       'indent': 2,
#       'description': 'Of whales, dolphins and porpoises (mammals of the order Cetacea); of manatees and dugongs (mammals of the order Sirenia); of seals, sea lions and walruses (mammals of the suborder Pinnipedia) | Other, including edible flours and meals of meat or meat offal:',
#       'superior': None,
#       'units': ['kg'],
#       'general': '2.3%',
#       'special': 'Free (A,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '20%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['mammals', 'mammals'],
#     'data': [{'htsno': '1504',
#       'indent': 0,
#       'description': 'Fats and oils and their fractions, of fish or marine mammals, whether or not refined, but not chemically modified:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': '',
#       'additionalDuties': '',
#       'addiitionalDuties': None},
#      {'htsno': '1504.10',
#       'indent': 1,
#       'description': 'Fish-liver oils and their fractions:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': '',
#       'additionalDuties': '',
#       'addiitionalDuties': None},
#      {'htsno': '1504.10.20.00',
#       'indent': 2,
#       'description': 'Cod',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '1504.10.40.00',
#       'indent': 2,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '2.5%',
#       'special': 'Free (A+,AU,BH,CL,CO,D,E, IL,JO,KR,MA,OM,P,PA,PE,S, SG)',
#       'other': '6.6¢/kg + 10%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '1504.20',
#       'indent': 1,
#       'description': 'Fats and oils and their fractions, of fish, other than liver oils:',
#       'superior': None,
#       'units': [],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': '',
#       'additionalDuties': '',
#       'addiitionalDuties': None},
#      {'htsno': '1504.20.20.00',
#       'indent': 2,
#       'description': 'Cod',
#       'superior': None,
#       'units': ['kg'],
#       'general': 'Free',
#       'special': '',
#       'other': 'Free',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '1504.20.40.00',
#       'indent': 2,
#       'description': 'Herring',
#       'superior': None,
#       'units': ['kg'],
#       'general': '1¢/kg',
#       'special': 'Free (A,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '8¢/kg',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '1504.20.60',
#       'indent': 2,
#       'description': 'Other',
#       'superior': None,
#       'units': [],
#       'general': '1.5¢/kg + 5%',
#       'special': 'Free (A,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '6.6¢/kg + 20%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.03.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '1504.20.60.20',
#       'indent': 3,
#       'description': 'Menhaden',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '1504.20.60.40',
#       'indent': 3,
#       'description': 'Other',
#       'superior': None,
#       'units': ['kg'],
#       'general': '',
#       'special': '',
#       'other': '',
#       'footnotes': [],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None},
#      {'htsno': '1504.30.00.00',
#       'indent': 1,
#       'description': 'Fats and oils and their fractions, of marine mammals',
#       'superior': None,
#       'units': ['kg'],
#       'general': '1.7¢/kg + 5%',
#       'special': 'Free (A,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#       'other': '6.6¢/kg + 20%',
#       'footnotes': [{'columns': ['general'],
#         'marker': '1',
#         'value': 'See 9903.88.15. ',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}],
#  [{'matchedInformation': {'keyword': ['mammals'],
#     'data': [{'htsno': '9902.12.50',
#       'indent': 0,
#       'description': 'Carrying cases of hard plastics, each with handle and door of plastics and with no door of metal, the foregoing designed for use for reptiles or amphibians and not for the housing or transport of mammals, measuring not over 381 mm on any side (provided for in subheading 4202.99.90)',
#       'superior': None,
#       'units': [],
#       'general': 'Free',
#       'special': 'No change',
#       'other': 'No change',
#       'footnotes': [{'columns': ['stat', 'units'],
#         'marker': '1',
#         'value': 'See chapter 99 statistical note 1.',
#         'type': 'endnote'}],
#       'quotaQuantity': None,
#       'additionalDuties': None,
#       'addiitionalDuties': None}]},
#    'match': True}]]
